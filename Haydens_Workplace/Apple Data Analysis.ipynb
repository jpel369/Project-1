# %%
import pandas as pd
import numpy as np
import csv

# %%
apple_df = pd.read_csv('AppleStore.csv')
apple_df = apple_df.drop(['id','size_bytes', 'rating_count_ver', 'user_rating_ver', 'ver', 'vpp_lic','Unnamed: 0','ipadSc_urls.num'], axis=1)
apple_df.head(50)
# Out:
#                                            track_name currency  price  \
# 0                                     PAC-MAN Premium      USD   3.99
# 1                           Evernote - stay organized      USD   0.00
# 2     WeatherBug - Local Weather, Radar, Maps, Alerts      USD   0.00
# 3   eBay: Best App to Buy, Sell, Save! Online Shop...      USD   0.00
# 4                                               Bible      USD   0.00
# 5                                    Shanghai Mahjong      USD   0.99
# 6              PayPal - Send and request money safely      USD   0.00
# 7                             Pandora - Music & Radio      USD   0.00
# 8                         PCalc - The Best Calculator      USD   9.99
# 9                                         Ms. PAC-MAN      USD   3.99
# 10                          Solitaire by MobilityWare      USD   4.99
# 11                                   SCRABBLE Premium      USD   7.99
# ...

# %%
#df_by_genre = apple_df.groupby(['lang.num'])
#print(df_by_genre.mean())
#apple_df.describe()


apple_df.sort_values(['rating_count_tot'])
# Out:
#                                              track_name currency  price  \
# 5163                             大人の出会いチャット  - 出会い系 アプリ      USD   0.00
# 5023                The Dance of the Little Water Drops      USD   2.99
# 1068                                  英単語ターゲット1900（5訂版）      USD   4.99
# 5033                                          喔豆-发现世间美味      USD   0.00
# 1060                              BarcodeReader「ICONIT」      USD   0.00
# 5041                                口袋理财（标准版）-上市公司报喜鸟投资      USD   0.00
# 5042                        友達 恋人探し であい ちゃっと sns -ギャルとも      USD   0.00
# 5047                            中学英文法総復習 パターンで覚える 瞬間英文法      USD   1.99
# 5020                                              HOLE.      USD   0.00
# 5049                              Brain15 − 脳トレ 無料パズル −      USD   0.00
# 5056                                         Go!Go!Cat!      USD   0.00
# 1049                                        激Jパチスロ 2027      USD   9.99
# ...
